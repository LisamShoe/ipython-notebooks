# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn is a library for making attractive and informative statistical graphics in Python. It is built on top of matplotlib and tightly integrated with the PyData stack, including support for numpy and pandas data structures and statistical routines from scipy and statsmodels.
#
# Library documentation: <a>http://stanford.edu/~mwaskom/software/seaborn/</a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# ### Themes

# %%
# global config settings to control things like style, font size, color palette etc.
sb.set(context="notebook", style="darkgrid", palette="dark")

# %%
# seaborn has some nice built-in color palette features
sb.palplot(sb.color_palette())
sb.palplot(sb.color_palette("husl", 8))
sb.palplot(sb.color_palette("hls", 8))

# %%
# matplotlib colormap of evenly spaced colors
sb.palplot(sb.color_palette("coolwarm", 7))

# %%
# sequential palette with linear increase in brightness
sb.palplot(sb.cubehelix_palette(8))

# %%
# palettes are used in a plot via the color paramter (original: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.)
gammas = sb.load_dataset("gammas")
sb.tsplot(gammas, "timepoint", "subject", "ROI", "BOLD signal", color="muted")
# Out:
# C:\Users\Jon\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
#corrected, but not as smooth
sb.lineplot(x="timepoint", y="BOLD signal", hue="ROI", data=gammas, palette="muted")

# %% [markdown]
# ### Advanced Plots

# %%
# facetting histograms by subsets of data
sb.set(style="darkgrid")

tips = sb.load_dataset("tips")
g = sb.FacetGrid(tips, row="sex", col="time", margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, "total_bill", color="steelblue", bins=bins, lw=0)

# %%
# several distribution plot examples (original: colors aren't correct)
sb.set(style="white", palette="muted")
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sb.despine(left=True)

rs = np.random.RandomState(10)

b, g, r, p = sb.color_palette("muted", 4)

d = rs.normal(size=100)

sb.distplot(d, kde=False, color=b, ax=axes[0, 0])
sb.distplot(d, hist=False, rug=True, color=r, ax=axes[0, 1])
sb.distplot(d, hist=False, color=g, kde_kws={"shade": True}, ax=axes[1, 0])
sb.distplot(d, color=p, ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
# several distribution plot example (corrected colors)
sb.set(style="white", palette="muted")
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sb.despine(left=True)

rs = np.random.RandomState(10)

b, g, r, p = sb.color_palette("muted", 4)

d = rs.normal(size=100)

sb.distplot(d, kde=False, color="b", ax=axes[0, 0])
sb.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])
sb.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])
sb.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
# hexbin plot with marginal distributions (original UserWarning: JointGrid annotation)
from scipy.stats import kendalltau
sb.set(style="ticks")

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)
sb.jointplot(x, y, kind="hex", stat_func=kendalltau, color="#4CB391")
# Out:
# C:\Users\Jon\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
#I did not see a replacement for jointplot in the documentation

# %%
# faceted logistic regression
sb.set(style="darkgrid")
df = sb.load_dataset("titanic")

pal = dict(male="#6495ED", female="#F08080")
g = sb.lmplot("age", "survived", col="sex", hue="sex", data=df,
               palette=pal, y_jitter=.02, logistic=True)
g.set(xlim=(0, 80), ylim=(-.05, 1.05))

# %%
# linear regression with marginal distributions (color = sb.color_palette()[3] will show the right red color)
sb.set(style="darkgrid")
tips = sb.load_dataset("tips")
color = sb.color_palette()[2]
g = sb.jointplot("total_bill", "tip", data=tips, kind="reg",
                  xlim=(0, 60), ylim=(0, 12), color=color, height=7)

# %%
# time series factor plot (original code: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release)
sb.set(style="white")
planets = sb.load_dataset("planets")
years = np.arange(2000, 2015)
g = sb.factorplot("year", data=planets, palette="BuPu",
                   aspect=1.5, x_order=years)
g.set_xticklabels(step=2)
# Out:
# C:\Users\Jon\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# time series factor plot (corrected code incl 1989)
sb.set(style="white")
planets = sb.load_dataset("planets")
#years = np.arange(2000, 2015)
g = sb.catplot(x='year', data=planets, palette="BuPu", aspect=1.5, kind="count")
g.set_xticklabels(step=2)

# %%
# time series factor plot (corrected code to be the same as the example)
new_planets = planets[planets['year'] > 1999]
sb.set(style="white")
g = sb.catplot(x='year', data=new_planets, palette="BuPu", aspect=1.5, kind="count")
g.set_xticklabels(step=2)

# %%
# correlation matrix (original code: AttributeError: module 'seaborn' has no attribute 'corrplot')
sb.set(style="darkgrid")

rs = np.random.RandomState(33)
d = rs.normal(size=(100, 30))

f, ax = plt.subplots(figsize=(9, 9))
cmap = sb.blend_palette(["#00008B", "#6A5ACD", "#F0F8FF",
                          "#FFE6F8", "#C71585", "#8B0000"], as_cmap=True)
sb.corrplot(d, annot=False, sig_stars=False,
             diag_names=False, cmap=cmap, ax=ax)
f.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d1695bb9feca> in <module>
#       8 cmap = sb.blend_palette(["#00008B", "#6A5ACD", "#F0F8FF",
#       9                           "#FFE6F8", "#C71585", "#8B0000"], as_cmap=True)
# ---> 10 sb.corrplot(d, annot=False, sig_stars=False,
#      11              diag_names=False, cmap=cmap, ax=ax)
#      12 f.tight_layout()
#
# AttributeError: module 'seaborn' has no attribute 'corrplot'

# %%
# correlation matrix (corrected code)
sb.set(style="white")

rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 30)))
corr = d.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(9, 9))
cmap = sb.blend_palette(["#00008B", "#6A5ACD", "#F0F8FF",
                          "#FFE6F8", "#C71585", "#8B0000"], as_cmap=True)
sb.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
f.tight_layout()

# %%
# pair plot example (Original : erWarning: The `size` parameter has been renamed to `height`; pleaes update your code.)
sb.set(style="darkgrid")
df = sb.load_dataset("iris")
sb.pairplot(df, hue="species", size=2.5)
# Out:
# C:\Users\Jon\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
# pair plot example (hue now produces this graph instead of bars)
sb.set(style="darkgrid")
df = sb.load_dataset("iris")
sb.pairplot(df, hue="species", height=2.5)
